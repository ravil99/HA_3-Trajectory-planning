# %% [markdown]
# # Importing modules

# %%
from numpy import pi
import numpy as np

from matplotlib.pyplot import *
import functions as f
import FK_functions as fk

# %% [markdown]
# # 1. Calculating and plotting position, velocity, and acceleration trajectories of driving robot model
# #   from configuration q_0 to configuration q_f in joint space.

# %% [markdown]
# # 1.1 Joint positions and parameters

# %%
# q0, qf, v_max, a_max

j1 = [0, 90, 7, 4]
j2 = [0, 75, 7, 4]
j3 = [0, 60, 7, 4]
j4 = [0, 45, 3.5, 2]
j5 = [0, 30, 3.5, 2]
j6 = [0, 15, 3.5, 2]

j1_2 = [90, 120, 5, 2.5]
j2_2 = [75, 115, 7, 4]
j3_2 = [60, 90, 7, 4]
j4_2 = [45, 75, 3.5, 2]
j5_2 = [30, 60, 3.5, 2]
j6_2 = [15, 45, 3.5, 2]

t0=0

# %% [markdown]
# # 1.2 Calculating initial trajectories

# %%
# calculate trajectory time for each
j1_t = f.trajectory_time(j1)
j2_t = f.trajectory_time(j2)
j3_t = f.trajectory_time(j3)
j4_t = f.trajectory_time(j4)
j5_t = f.trajectory_time(j5)
j6_t = f.trajectory_time(j6)

# calculate each trajectory
T1, q1, v1, a1 = f.plan_trajectory(j1, j1_t)
T2, q2, v2, a2 = f.plan_trajectory(j2, j2_t)
T3, q3, v3, a3 = f.plan_trajectory(j3, j3_t)
T4, q4, v4, a4 = f.plan_trajectory(j4, j4_t)
T5, q5, v5, a5 = f.plan_trajectory(j5, j5_t)
T6, q6, v6, a6 = f.plan_trajectory(j6, j6_t)

# extract time params for plotting
_, t11, T11, tf1 = j1_t
_, t12, T12, tf2 = j2_t
_, t13, T13, tf3 = j3_t
_, t14, T14, tf4 = j4_t
_, t15, T15, tf5 = j5_t
_, t16, T16, tf6 = j6_t

# %% [markdown]
# # 1.3 Plotting initial trajectories

# %%
figure(figsize=(26, 24))

                                                    # Plotting for joint 1
# Printing q1
subplot(6, 3, 1)
plot(T1, q1, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, max(q1)+10])
hlines(j1[1], 0, tf1, linestyles='--', color='r', label=r"$q_{max}$")
vlines([t11, T11], 0, max(q1)+10, linestyles='--', linewidth=2)
legend()

# Printing v1
subplot(6, 3, 2)
plot(T1, v1, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, max(v1)+1])
hlines(j1[2], 0, tf1, linestyles='--', color='r', label=r"$v_{max}$")
vlines([t11, T11], 0, max(q1), linestyles='--', linewidth=2)
legend()

# Printing a1
subplot(6, 3, 3)
plot(T1, a1, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([min(a1)-1, max(a1)+1])
vlines([t11, T11], min(a1)-1, max(a1)+1, linestyles='--', linewidth=2)
legend()

                                                    # Plotting for joint 2
# Printing q2
subplot(6, 3, 4)
plot(T2, q2, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, max(q2)+10])
hlines(j2[1], 0, tf1, linestyles='--', color='r', label=r"$q_{max}$")
vlines([t12, T12], 0, max(q2)+10, linestyles='--', linewidth=2)
legend()

# Printing v2
subplot(6, 3, 5)
plot(T2, v2, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, max(v2)+1])
hlines(j2[2], 0, tf1, linestyles='--', color='r', label=r"$v_{max}$")
vlines([t12, T12], 0, max(q2), linestyles='--', linewidth=2)
legend()

# Printing a2
subplot(6, 3, 6)
plot(T2, a2, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([min(a2)-1, max(a2)+1])
vlines([t12, T12], min(a2)-1, max(a2)+1, linestyles='--', linewidth=2)
legend()

                                                    # Plotting for joint 3
# Printing q3
subplot(6, 3, 7)
plot(T3, q3, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, max(q3)+10])
hlines(j3[1], 0, tf1, linestyles='--', color='r', label=r"$q_{max}$")
vlines([t13, T13], 0, max(q3)+10, linestyles='--', linewidth=2)
legend()

# Printing v3
subplot(6, 3, 8)
plot(T3, v3, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, max(v3)+1])
hlines(j3[2], 0, tf1, linestyles='--', color='r', label=r"$v_{max}$")
vlines([t13, T13], 0, max(q3), linestyles='--', linewidth=2)
legend()

# Printing a3
subplot(6, 3, 9)
plot(T3, a3, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([min(a3)-1, max(a3)+1])
vlines([t13, T13], min(a3)-1, max(a3)+1, linestyles='--', linewidth=2)
legend()

                                                    # Plotting for joint 4
# Printing q4
subplot(6, 3, 10)
plot(T4, q4, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, max(q4)+10])
hlines(j4[1], 0, tf1, linestyles='--', color='r', label=r"$q_{max}$")
vlines([t14, T14], 0, max(q4)+10, linestyles='--', linewidth=2)
legend()

# Printing v4
subplot(6, 3, 11)
plot(T4, v4, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, max(v4)+1])
hlines(j4[2], 0, tf1, linestyles='--', color='r', label=r"$v_{max}$")
vlines([t14, T14], 0, max(q4), linestyles='--', linewidth=2)
legend()

# Printing a4
subplot(6, 3, 12)
plot(T4, a4, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([min(a4)-1, max(a4)+1])
vlines([t14, T14], min(a4)-1, max(a4)+1, linestyles='--', linewidth=2)
legend()

                                                    # Plotting for joint 5
# Printing q5
subplot(6, 3, 13)
plot(T5, q5, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, max(q5)+10])
hlines(j5[1], 0, tf1, linestyles='--', color='r', label=r"$q_{max}$")
vlines([t15, T15], 0, max(q4)+10, linestyles='--', linewidth=2)
legend()

# Printing v5
subplot(6, 3, 14)
plot(T5, v5, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, max(v5)+1])
hlines(j5[2], 0, tf1, linestyles='--', color='r', label=r"$v_{max}$")
vlines([t15, T15], 0, max(q5), linestyles='--', linewidth=2)
legend()

# Printing a5
subplot(6, 3, 15)
plot(T5, a5, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([min(a5)-1, max(a5)+1])
vlines([t15, T15], min(a5)-1, max(a5)+1, linestyles='--', linewidth=2)
legend()

                                                    # Plotting for joint 6
# Printing q6
subplot(6, 3, 16)
plot(T6, q6, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, max(q6)+10])
hlines(j6[1], 0, tf1, linestyles='--', color='r', label=r"$q_{max}$")
vlines([t16, T16], 0, max(q6)+10, linestyles='--', linewidth=2)
legend()

# Printing v6
subplot(6, 3, 17)
plot(T6, v6, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, max(v6)+1])
hlines(j6[2], 0, tf1, linestyles='--', color='r', label=r"$v_{max}$")
vlines([t16, T16], 0, max(q6), linestyles='--', linewidth=2)
legend()

# Printing a6
subplot(6, 3, 18)
plot(T6, a6, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([min(a6)-1, max(a6)+1])
vlines([t16, T16], min(a6)-1, max(a6)+1, linestyles='--', linewidth=2)
legend()

show()

# %% [markdown]
# # 2. Synchroning 6 joints to start and end motion at the same time.

# %% [markdown]
# # 2.1 Synchronization

# %%
# refine time parameters

t1 = max(t11, t12, t13, t14, t15, t16)
print(f"J1 rise time: {t11}s, J2 rise time: {t12}s, J3 rise time: {t13}s"
      f"J4 rise time: {t14}s, J5 rise time: {t15}s, J6 rise time: {t16}s"
      f"synchronized rise time: {t1}\n")

dwell = max(T11 - t11, T12 - t12, T13 - t13, T14 - t14, T15 - t15, T16 - t16)

print(f"J1 dwell time: {T11-t11}s, J2 dwell time: {T12-t12}s, J3 dwell time: {T13-t13}s"
      f"J4 dwell time: {T14-t14}s, J5 dwell time: {T15-t15}s, J6 dwell time: {T16-t16}s"
      f"synchronized dwell time: {dwell}\n")

T = dwell+t1
tf = T + t1
print("Synchronized trajectory time = {} + {} + {} = {}s\n".format(t1, dwell, t1, tf))

t_params = [t0, t1, T, tf]
print(f't_params: {t_params}')

# recalculate velocity parameters
dq1_m = (j1[1]-j1[0])/T
dq2_m = (j2[1]-j2[0])/T
dq3_m = (j3[1]-j3[0])/T
dq4_m = (j4[1]-j4[0])/T
dq5_m = (j5[1]-j5[0])/T
dq6_m = (j6[1]-j6[0])/T

# recalculate acceleration parameters
ddq1_m = dq1_m/t1
ddq2_m = dq2_m/t1
ddq3_m = dq3_m/t1
ddq4_m = dq4_m/t1
ddq5_m = dq5_m/t1
ddq6_m = dq6_m/t1


print("Joint 1 velocity modified from {} to {} and acceleration from {} to {}".format(
    j1[2], dq1_m, j1[3], ddq1_m))
print("Joint 2 velocity modified from {} to {} and acceleration from {} to {}".format(
    j2[2], dq2_m, j2[3], ddq2_m))
print("Joint 3 velocity modified from {} to {} and acceleration from {} to {}".format(
    j3[2], dq3_m, j3[3], ddq3_m))
print("Joint 4 velocity modified from {} to {} and acceleration from {} to {}".format(
    j4[2], dq4_m, j4[3], ddq4_m))
print("Joint 5 velocity modified from {} to {} and acceleration from {} to {}".format(
    j5[2], dq5_m, j5[3], ddq5_m))
print("Joint 6 velocity modified from {} to {} and acceleration from {} to {}".format(
    j6[2], dq6_m, j6[3], ddq6_m))

# update parameters
j1[2:] = [dq1_m, ddq1_m]
j2[2:] = [dq2_m, ddq2_m]
j3[2:] = [dq3_m, ddq3_m]
j4[2:] = [dq4_m, ddq4_m]
j5[2:] = [dq5_m, ddq5_m]
j6[2:] = [dq6_m, ddq6_m]
# Out:
# J1 rise time: 1.75s, J2 rise time: 1.75s, J3 rise time: 1.75sJ4 rise time: 1.75s, J5 rise time: 1.75s, J6 rise time: 1.75ssynchronized rise time: 1.75
#
# J1 dwell time: 11.107142857142858s, J2 dwell time: 8.964285714285714s, J3 dwell time: 6.821428571428571sJ4 dwell time: 11.107142857142858s, J5 dwell time: 6.821428571428571s, J6 dwell time: 2.5357142857142856ssynchronized dwell time: 11.107142857142858
#
# Synchronized trajectory time = 1.75 + 11.107142857142858 + 1.75 = 14.607142857142858s
#
# t_params: [0, 1.75, 12.857142857142858, 14.607142857142858]
# Joint 1 velocity modified from 7 to 7.0 and acceleration from 4 to 4.0
# Joint 2 velocity modified from 7 to 5.833333333333333 and acceleration from 4 to 3.333333333333333
# Joint 3 velocity modified from 7 to 4.666666666666666 and acceleration from 4 to 2.6666666666666665
# Joint 4 velocity modified from 3.5 to 3.5 and acceleration from 2 to 2.0
# ...

# %%
print(f"{j1}\n {j2}\n {j3}\n {j4}\n {j5}\n {j6}")
# Out:
# [0, 90, 7.0, 4.0]
#  [0, 75, 5.833333333333333, 3.333333333333333]
#  [0, 60, 4.666666666666666, 2.6666666666666665]
#  [0, 45, 3.5, 2.0]
#  [0, 30, 2.333333333333333, 1.3333333333333333]
#  [0, 15, 1.1666666666666665, 0.6666666666666666]

# %% [markdown]
# # 2.2 Calculating new trajectories

# %%
#calculate each trajectory
T1,q1,v1,a1 = f.plan_trajectory(j1, t_params)
T2,q2,v2,a2 = f.plan_trajectory(j2, t_params)
T3,q3,v3,a3 = f.plan_trajectory(j3, t_params)
T4,q4,v4,a4 = f.plan_trajectory(j4, t_params)
T5,q5,v5,a5 = f.plan_trajectory(j5, t_params)
T6,q6,v6,a6 = f.plan_trajectory(j6, t_params)

#extract time params for plotting
_,t11,T11,tf1 = t_params
_,t12,T12,tf2 = t_params
_,t13,T13,tf3 = t_params
_,t14,T14,tf4 = t_params
_,t15,T15,tf5 = t_params
_,t16,T16,tf6 = t_params

q_max = max(max(q1), max(q2), max(q3), max(q4), max(q5), max(q6))
v_max = max(max(v1), max(v2), max(v3), max(v4), max(v5), max(v6))
a_max = max(max(a1), max(a2), max(a3), max(a4), max(a5), max(a6))

# %% [markdown]
# # 2.3 Plotting each trajectory

# %%
figure(figsize=(26, 24))

                                                    # Plotting for joint 1
# Printing q1
subplot(6, 3, 1)
plot(T1, q1, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, q_max + 10])
hlines(j1[1], 0, tf1, linestyles='--', color='r', label=r"$q_{max}$")
vlines([t11, T11], 0, q_max+10, linestyles='--', linewidth=2)
legend()

# Printing v1
subplot(6, 3, 2)
plot(T1, v1, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, v_max + 1])
hlines(j1[2], 0, tf1, linestyles='--', color='r', label=r"$v_{max}$")
vlines([t11, T11], 0, q_max, linestyles='--', linewidth=2)
legend()

# Printing a1
subplot(6, 3, 3)
plot(T1, a1, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([-a_max - 1, a_max + 1])
vlines([t11, T11], -a_max - 1 , a_max + 1, linestyles='--', linewidth=2)
legend()

                                                    # Plotting for joint 2
# Printing q2
subplot(6, 3, 4)
plot(T2, q2, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, q_max + 10])
hlines(j2[1], 0, tf1, linestyles='--', color='r', label=r"$q_{max}$")
vlines([t12, T12], 0, q_max+10, linestyles='--', linewidth=2)
legend()

# Printing v2
subplot(6, 3, 5)
plot(T2, v2, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, v_max + 1])
hlines(j2[2], 0, tf1, linestyles='--', color='r', label=r"$v_{max}$")
vlines([t12, T12], 0, q_max, linestyles='--', linewidth=2)
legend()

# Printing a2
subplot(6, 3, 6)
plot(T2, a2, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([-a_max - 1, a_max + 1])
vlines([t12, T12], -a_max - 1 , a_max + 1, linestyles='--', linewidth=2)
legend()

                                                    # Plotting for joint 3
# Printing q3
subplot(6, 3, 7)
plot(T3, q3, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, q_max + 10])
hlines(j3[1], 0, tf1, linestyles='--', color='r', label=r"$q_{max}$")
vlines([t13, T13], 0, q_max+10, linestyles='--', linewidth=2)
legend()

# Printing v3
subplot(6, 3, 8)
plot(T3, v3, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, v_max + 1])
hlines(j3[2], 0, tf1, linestyles='--', color='r', label=r"$v_{max}$")
vlines([t13, T13], 0, q_max, linestyles='--', linewidth=2)
legend()

# Printing a3
subplot(6, 3, 9)
plot(T3, a3, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([-a_max - 1, a_max + 1])
vlines([t13, T13], -a_max - 1 , a_max + 1, linestyles='--', linewidth=2)
legend()

                                                    # Plotting for joint 4
# Printing q4
subplot(6, 3, 10)
plot(T4, q4, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, q_max + 10])
hlines(j4[1], 0, tf1, linestyles='--', color='r', label=r"$q_{max}$")
vlines([t14, T14], 0, q_max+10, linestyles='--', linewidth=2)
legend()

# Printing v4
subplot(6, 3, 11)
plot(T4, v4, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, v_max + 1])
hlines(j4[2], 0, tf1, linestyles='--', color='r', label=r"$v_{max}$")
vlines([t14, T14], 0, q_max, linestyles='--', linewidth=2)
legend()

# Printing a4
subplot(6, 3, 12)
plot(T4, a4, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([-a_max - 1, a_max + 1])
vlines([t14, T14], -a_max - 1, a_max + 1, linestyles='--', linewidth=2)
legend()

                                                    # Plotting for joint 5
# Printing q5
subplot(6, 3, 13)
plot(T5, q5, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, q_max + 10])
hlines(j5[1], 0, tf1, linestyles='--', color='r', label=r"$q_{max}$")
vlines([t15, T15], 0, q_max + 10, linestyles='--', linewidth=2)
legend()

# Printing v5
subplot(6, 3, 14)
plot(T5, v5, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, v_max + 1])
hlines(j5[2], 0, tf1, linestyles='--', color='r', label=r"$v_{max}$")
vlines([t15, T15], 0, q_max, linestyles='--', linewidth=2)
legend()

# Printing a5
subplot(6, 3, 15)
plot(T5, a5, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([-a_max - 1, a_max + 1])
vlines([t15, T15], -a_max - 1, a_max + 1, linestyles='--', linewidth=2)
legend()

                                                    # Plotting for joint 6
# Printing q6
subplot(6, 3, 16)
plot(T6, q6, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, q_max + 10])
hlines(j6[1], 0, tf1, linestyles='--', color='r', label=r"$q_{max}$")
vlines([t16, T16], 0, q_max + 10, linestyles='--', linewidth=2)
legend()

# Printing v6
subplot(6, 3, 17)
plot(T6, v6, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([0, v_max + 1])
hlines(j6[2], 0, tf1, linestyles='--', color='r', label=r"$v_{max}$")
vlines([t16, T16], 0, q_max, linestyles='--', linewidth=2)
legend()

# Printing a6
subplot(6, 3, 18)
plot(T6, a6, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha=0.7)
grid(True)
xlim([0, max(tf1, tf2, tf3, tf4, tf5, tf6 )])
ylim([-a_max - 1, a_max + 1])
vlines([t16, T16], -a_max - 1, a_max + 1, linestyles='--', linewidth=2)
legend()

show()

# %% [markdown]
# # 3. Numerical control

# %%
delta_t = 0.002

if t1 % delta_t != 0:
    num_t1 = (t1 // delta_t) * delta_t + delta_t

if T % delta_t != 0:
    T = (T // delta_t) * delta_t + delta_t

if tf % delta_t != 0:
    tf = (tf // delta_t) * delta_t + delta_t

t_params = [t0, t1, T, tf]
print("Synchronized trajectory time = {} + {} + {} = {}s\n".format(t1, T - t1, t1, tf))

# recalculate velocity parameters
dq1_m = (j1[1]-j1[0])/T
dq2_m = (j2[1]-j2[0])/T
dq3_m = (j3[1]-j3[0])/T
dq4_m = (j4[1]-j4[0])/T
dq5_m = (j5[1]-j5[0])/T
dq6_m = (j6[1]-j6[0])/T

# recalculate acceleration parameters
ddq1_m = dq1_m/t1
ddq2_m = dq2_m/t1
ddq3_m = dq3_m/t1
ddq4_m = dq4_m/t1
ddq5_m = dq5_m/t1
ddq6_m = dq6_m/t1

# update parameters
j1[2:] = [dq1_m, ddq1_m]
j2[2:] = [dq2_m, ddq2_m]
j3[2:] = [dq3_m, ddq3_m]
j4[2:] = [dq4_m, ddq4_m]
j5[2:] = [dq5_m, ddq5_m]
j6[2:] = [dq6_m, ddq6_m]

print('q_0, q_f, v_max, a_max')
print(f"{j1}\n {j2}\n {j3}\n {j4}\n {j5}\n {j6}")
# Out:
# Synchronized trajectory time = 1.75 + 11.108 + 1.75 = 14.608s
#
# q_0, q_f, v_max, a_max
# [0, 90, 6.99953336444237, 3.9997333511099256]
#  [0, 75, 5.832944470368642, 3.333111125924938]
#  [0, 60, 4.666355576294913, 2.6664889007399504]
#  [0, 45, 3.499766682221185, 1.9998666755549628]
#  [0, 30, 2.3331777881474567, 1.3332444503699752]
#  [0, 15, 1.1665888940737283, 0.6666222251849876]

# %% [markdown]
# # 4. Calculating propagated error

# %% [markdown]
# # 4.1 Calculating new angles

# %%
T1,q1,v1,a1 = f.plan_trajectory(j1, t_params)
T2,q2,v2,a2 = f.plan_trajectory(j2, t_params)
T3,q3,v3,a3 = f.plan_trajectory(j3, t_params)
T4,q4,v4,a4 = f.plan_trajectory(j4, t_params)
T5,q5,v5,a5 = f.plan_trajectory(j5, t_params)
T6,q6,v6,a6 = f.plan_trajectory(j6, t_params)

#extract time params for plotting
_,t11,T11,tf1 = t_params
_,t12,T12,tf2 = t_params
_,t13,T13,tf3 = t_params
_,t14,T14,tf4 = t_params
_,t15,T15,tf5 = t_params
_,t16,T16,tf6 = t_params


original_q = [j1[1], j2[1], j3[1], j4[1], j5[1], j6[1]]
print(original_q)

new_q = [q1[-1], q2[-1], q3[-1], q4[-1], q5[-1], q6[-1]]
print(new_q)
# Out:
# [90, 75, 60, 45, 30, 15]
# [90.0, 75.0, 60.0, 45.0, 30.0, 15.0]

# %% [markdown]
# # 4.2 Using FK to get end - effector position and calculate error

# %%
orig_transform_table = fk.make_table(original_q)
orig_fk = fk.serial_transform(orig_transform_table)[-1]
print(f'{orig_fk}\n')


new_transform_table = fk.make_table(new_q)
new_fk = fk.serial_transform(orig_transform_table)[-1]
print(f'{new_fk}\n')

pos_orig = orig_fk[0:3,3]
pos_new = new_fk [0:3,3]

diff = pos_new - pos_orig
print(f'Propagated error after numerical control is: {diff}')
# Out:
# [[ 0.79989459  0.16982733  0.57561039  0.17663304]
#  [ 0.2803479   0.74230659 -0.60859344  0.02284126]
#  [-0.53063519  0.64818177  0.54615629  0.54357944]
#  [ 0.          0.          0.          1.        ]]
#
# [[ 0.79989459  0.16982733  0.57561039  0.17663304]
#  [ 0.2803479   0.74230659 -0.60859344  0.02284126]
#  [-0.53063519  0.64818177  0.54615629  0.54357944]
#  [ 0.          0.          0.          1.        ]]
#
# Propagated error after numerical control is: [0. 0. 0.]

# %% [markdown]
# # 5. Trajectory between 3 consequent points. Using polynomial

# %% [markdown]
# # 5.1 Setting the constraints

# %%
t0 = 0
t1 = 14.608
t2 = 2*t1

q_0 = 0
q_1 = 90
q_2 = 60

v_0 = 0
v_1 = 2
v_2 = 0

a_0 = 0
a_1 = 1
a_2 = 0

# %% [markdown]
# # 5.2 Cubic Polinomial

# %%
t0 = 0
t1 = 14.608
t2 = 2*t1

coef = np.zeros((4,4), dtype = np.float64)
coef[0,:] = [ t0 ** 3, t0 ** 2, t0 , 1 ]
coef[1,:] = [ t1 ** 3, t1 ** 2, t1 , 1 ]
coef[2,:] = [ 3 * t0 ** 2, 2* t0, 1 , 0 ]
coef[3,:] = [ 3 * t1 ** 2, 2* t1, 1 , 0  ]

coef_2 = np.zeros((4,4), dtype = np.float64)
coef_2[0,:] = [ t1 ** 3, t1 ** 2, t1 , 1 ]
coef_2[1,:] = [ t2 ** 3, t2 ** 2, t2 , 1  ]
coef_2[2,:] = [ 3 * t1 ** 2, 2* t1, 1 , 0]
coef_2[3,:] = [ 3 * t2 ** 2, 2* t2, 1 , 0 ]

# q0, qf, v0, vf, a0, af
q_0 = 0
q_1 = 90
q_2 = 60

v_0 = 0
v_1 = 2
v_2 = 0


first_const = [q_0, q_1, v_0, v_1]
second_const = [q_1, q_2, v_1, v_2]

trj_first = np.matmul(np.linalg.inv(coef), first_const)

trj_second = np.matmul(np.linalg.inv(coef_2), second_const)

print(type(trj_first))
print(trj_first)

# From point 1 to point 2
T1,q1,v1,a1 = f.cubic_polynom(trj_first, t0, t1)

T1 = list(T1)

print(f'T1: {len(T1)}, {type(T1)}, {T1[0]}, {T1[-1]}  \n')
print(f'q1: {len(q1)}, {type(q1)}, {q1[0]}, {q1[-1]}  \n')
print(f'v1: {len(v1)}, {type(v1)}, {v1[0]}, {v1[-1]}  \n')
print(f'a1: {len(a1)}, {type(a1)}, {a1[0]}, {a1[-1]}  \n')

# From point 2 to point 3
T2,q2,v2,a2 = f.cubic_polynom(trj_second, t1, t2)

T2 = list(T2)

print(f'T2: {len(T2)}, {type(T2)}, {T2[0]}, {T2[-1]}  \n')
print(f'q2: {len(q2)}, {type(q2)}, {q2[0]}, {q2[-1]}  \n')
print(f'v2: {len(v2)}, {type(v2)}, {v2[0]}, {v2[-1]}  \n')
print(f'a2: {len(a2)}, {type(a2)}, {a2[0]}, {a2[-1]}  \n')
# Out:
# <class 'numpy.ndarray'>
# [-0.04837077  1.1283559   0.          0.        ]
# T1: 3000, <class 'list'>, 0.0, 14.608
#
# q1: 3000, <class 'list'>, 0.0, 90.00000000000003
#
# v1: 3000, <class 'list'>, 0.0, 2.0000000000000036
#
# a1: 3000, <class 'list'>, 2.256711801902421, -1.9828892389232307
#
# T2: 3000, <class 'list'>, 14.608, 29.216
#
# q2: 3000, <class 'list'>, 90.0, 59.999999999999886
#
# v2: 3000, <class 'list'>, 1.999999999999993, -1.4210854715202004e-14
#
# a2: 3000, <class 'list'>, -1.3911565809189153, 1.1173340179397249

# %%
# Printing

T_print = T1 + T2
q_print = q1 + q2
v_print = v1 + v2
a_print = a1 + a2

figure(figsize=(12,12))

subplot(311)
plot(T_print,q_print, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha = 0.7)
grid(True)
xlim([0, max(T_print) + 1])
ylim([0,max(q_print)+10])
hlines(q_2, 0,t2, linestyles='--', color='r')
vlines([t1,t2], 0, max(q_print)+10, linestyles='--', linewidth=2)
legend()

subplot(312)
plot(T_print,v_print, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha = 0.7)
grid(True)
xlim([0,max(T_print) + 1])
ylim([min(v_print)-1,max(v_print)+1])
vlines([t1,t2], min(v_print)-1,max(v_print)+1, linestyles='--', linewidth=2)
legend()

subplot(313)
plot(T_print,a_print, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha = 0.7)
grid(True)
xlim([0,max(T_print) + 1])
ylim([min(a_print)-1,max(a_print)+1])
vlines([t1,t2], min(a_print)-1,max(a_print)+1, linestyles='--', linewidth=2)
legend()


show()

# %% [markdown]
# # 5.3 Quintic Polynomial

# %%
t0 = 0
t1 = 14.608
t2 = 2*t1

coef = np.zeros((6,6), dtype = np.float64)
coef[0,:] = [ t0 ** 5, t0 ** 4, t0 ** 3, t0 ** 2, t0, 1 ]
coef[1,:] = [ t1 ** 5, t1 ** 4, t1 ** 3, t1 ** 2, t1, 1  ]
coef[2,:] = [ 5 * t0 ** 4, 4 * t0 ** 3, 3 * t0 ** 2, 2 * t0, 1, 0 ]
coef[3,:] = [ 5 * t1 ** 4, 4 * t1 ** 3, 3 * t1 ** 2, 2 * t1, 1, 0 ]
coef[4,:] = [ 20 * t0 ** 3, 12 * t0 ** 2, 6 * t0 , 1, 0, 0 ]
coef[5,:] = [ 20 * t1 ** 3, 12 * t1 ** 2, 6 * t1 , 1, 0, 0 ]

coef_2 = np.zeros((6,6), dtype = np.float64)
coef_2[0,:] = [ t1 ** 5, t1 ** 4, t1 ** 3, t1 ** 2, t1, 1 ]
coef_2[1,:] = [ t2 ** 5, t2 ** 4, t2 ** 3, t2 ** 2, t2, 1  ]
coef_2[2,:] = [ 5 * t1 ** 4, 4 * t1 ** 3, 3 * t1 ** 2, 2 * t1, 1, 0 ]
coef_2[3,:] = [ 5 * t2 ** 4, 4 * t2 ** 3, 3 * t2 ** 2, 2 * t2, 1, 0 ]
coef_2[4,:] = [ 20 * t1 ** 3, 12 * t1 ** 2, 6 * t1 , 1, 0, 0 ]
coef_2[5,:] = [ 20 * t2 ** 3, 12 * t2 ** 2, 6 * t2 , 1, 0, 0 ]


first_const = [q_0, q_1, v_0, v_1, a_0, a_1]
second_const = [q_1, q_2, v_1, v_2, a_1, a_2]

trj_first = np.matmul(np.linalg.inv(coef), first_const)

trj_second = np.matmul(np.linalg.inv(coef_2), second_const)

print(type(trj_first))
print(trj_first)

# From point 1 to point 2

T1,q1,v1,a1 = f.quintic_polynom(trj_first, t0, t1)

T1 = list(T1)

print(f'T1: {len(T1)}, {type(T1)}, {T1[0]}, {T1[-1]}  \n')
print(f'q1: {len(q1)}, {type(q1)}, {q1[0]}, {q1[-1]}  \n')
print(f'v1: {len(v1)}, {type(v1)}, {v1[0]}, {v1[-1]}  \n')
print(f'a1: {len(a1)}, {type(a1)}, {a1[0]}, {a1[-1]}  \n')

T2,q2,v2,a2 = f.quintic_polynom(trj_second, t1, t2)

# From point 2 to point 3

T2 = list(T2)

print(f'T2: {len(T2)}, {type(T2)}, {T2[0]}, {T2[-1]}  \n')
print(f'q2: {len(q2)}, {type(q2)}, {q2[0]}, {q2[-1]}  \n')
print(f'v2: {len(v2)}, {type(v2)}, {v2[0]}, {v2[-1]}  \n')
print(f'a2: {len(a2)}, {type(a2)}, {a2[0]}, {a2[-1]}  \n')
# Out:
# <class 'numpy.ndarray'>
# [ 0.00084042 -0.02984136  0.28545401  0.          0.          0.        ]
# T1: 3000, <class 'list'>, 0.0, 14.608
#
# q1: 3000, <class 'list'>, 0.0, 90.0
#
# v1: 3000, <class 'list'>, 0.0, 1.9999999999999432
#
# a1: 3000, <class 'list'>, 0.0, 1.0000000000000036
#
# T2: 3000, <class 'list'>, 14.608, 29.216
#
# q2: 3000, <class 'list'>, 90.00000000000091, 60.00000000000273
#
# v2: 3000, <class 'list'>, 2.0, 1.1368683772161603e-13
#
# a2: 3000, <class 'list'>, -9.445241213057901, -10.445241213057916

# %%
# Printing 

T_print = T1 + T2
q_print = q1 + q2
v_print = v1 + v2
a_print = a1 + a2

figure(figsize=(12,12))

subplot(311)
plot(T_print,q_print, linewidth=2, label="q")
xlabel('t (s)', fontsize=18)
ylabel(r'q(t) ($\degree$)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha = 0.7)
grid(True)
xlim([0, max(T_print) + 1])
ylim([0,max(q_print)+10])
hlines(q_2, 0,t2, linestyles='--', color='r')
vlines([t1,t2], 0, max(q_print)+10, linestyles='--', linewidth=2)
legend()

subplot(312)
plot(T_print,v_print, linewidth=2, label="v")
xlabel('t (s)', fontsize=18)
ylabel(r'v(t) ($\degree$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha = 0.7)
grid(True)
xlim([0,max(T_print) + 1])
ylim([min(v_print)-1,max(v_print)+1])
vlines([t1,t2], min(v_print)-1,max(v_print)+1, linestyles='--', linewidth=2)
legend()

subplot(313)
plot(T_print,a_print, linewidth=3, label="a")
xlabel('t (s)', fontsize=18)
ylabel(r'a(t) ($\degree^2$/s)', fontsize=18)
grid(color='black', linestyle='--', linewidth=1.0, alpha = 0.7)
grid(True)
xlim([0,max(T_print) + 1])
ylim([min(a_print)-1,max(a_print)+1])
vlines([t1,t2], min(a_print)-1,max(a_print)+1, linestyles='--', linewidth=2)
legend()


show()

# %% [markdown]
# # 6. Trajectory junction

# %%
from Classes import Joint

# for joints j1 .. j3 = V_max = 7 and A_max = 4

j1 = Joint([0, 60, 45, 90], 7, 4)
j2 = Joint([0, 60, 30, 80], 7, 4)
j3 = Joint([0, 20, 10, 45], 7, 4)

# for joints j4 .. j6 = V_max = 3.5 and A_max = 2

j4 = Joint([0, 30, 60, 90], 3.5, 2)
j5 = Joint([0, 80, 40, 20], 3.5, 2)
j6 = Joint([0, 60, 30, 45], 3.5, 2)
joints = [j1, j2, j3, j4, j5, j6]

for joint in joints:
    joint.trajectory_junction_ratio = 1
    joint.calculate_path()
    joint.numerical_control()
    joint.plot_path_Dots()
